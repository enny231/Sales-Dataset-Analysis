# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\Eniola\Downloads\sales_data.csv')
df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
df.shape
# Out:
# (113036, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
df.corr()
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.007635     -0.014296       -0.002412   0.003133
# Year           -0.007635  1.000000      0.040994        0.123169  -0.217575
# Customer_Age   -0.014296  0.040994      1.000000        0.026887  -0.021374
# Order_Quantity -0.002412  0.123169      0.026887        1.000000  -0.515835
# Unit_Cost       0.003133 -0.217575     -0.021374       -0.515835   1.000000
# Unit_Price      0.003207 -0.213673     -0.020262       -0.515925   0.997894
# Profit          0.004623 -0.181525      0.004319       -0.238863   0.741020
# Cost            0.003329 -0.215604     -0.016013       -0.340382   0.829869
# Revenue         0.003853 -0.208673     -0.009326       -0.312895   0.817865
#
#                 Unit_Price    Profit      Cost   Revenue
# Day               0.003207  0.004623  0.003329  0.003853
# Year             -0.213673 -0.181525 -0.215604 -0.208673
# ...

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
#What's the mean of Customers_Age?
df.Customer_Age.mean()
# Out:
# 35.91921157861212

# %%
#What's the mean of Order_Quantity?
df.head()
df.Order_Quantity.mean()
# Out:
# 11.901659648253654

# %%
#How many sales per year do we have?
df.head()
df.Year.value_counts()
# Out:
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: Year, dtype: int64

# %%
#How many sales per month do we have?
df.head()
df.Month.value_counts()
# Out:
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: Month, dtype: int64

# %%
#Which country has the most sales quantity of sales?
df.head()
df.Country.value_counts()
# Out:
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: Country, dtype: int64

# %%
#Create a list of every product sold
df.head()
df.Product.value_counts().head(50 )
# Out:
# Water Bottle - 30 oz.              10794
# Patch Kit/8 Patches                10416
# Mountain Tire Tube                  6816
# AWC Logo Cap                        4358
# Sport-100 Helmet, Red               4220
# Road Tire Tube                      4176
# Sport-100 Helmet, Black             4152
# Fender Set - Mountain               4032
# Sport-100 Helmet, Blue              3788
# Touring Tire Tube                   3702
# Road Bottle Cage                    2640
# Mountain Bottle Cage                2444
# Bike Wash - Dissolver               1804
# HL Mountain Tire                    1800
# LL Road Tire                        1686
# ML Road Tire                        1396
# ML Mountain Tire                    1376
# Hydration Pack - 70 oz.             1332
# Mountain-200 Black, 38              1208
# Mountain-200 Silver, 38             1106
# Mountain-200 Silver, 42             1054
# HL Road Tire                        1006
# Half-Finger Gloves, S                994
# ...

# %%
#Can you see any relationship between Unit_Cost and Unit_Price?
df.head()
df.plot(kind='scatter', x='Unit_Cost', y='Unit_Price',figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
#Can you see any relationship between Order_Quantity and Profit?
df.head()
df.plot(kind='scatter',x='Order_Quantity', y='Profit',figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Order_Quantity', ylabel='Profit'>

# %%
#Can you see any relationship between Profit per Country?
df.head()
df[['Profit', 'Country']].boxplot(by='Country', figsize=(10,10))
# Out:
# <AxesSubplot:title={'center':'Profit'}, xlabel='[Country]'>

# %%
#Can you see any relationship between the Customer_Age per Country?
df.head()
df[['Customer_Age','Country']].boxplot(by='Country',figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'Customer_Age'}, xlabel='[Country]'>

# %%
#Add and calculate a new Calculated_Date column
df['Year']=df['Year'].astype(str)
df['Day']=df['Day'].astype(str)
df.head()
df['Calculated_Date'] = df['Day']+ ' '+  df['Month']+' ' + df['Year']
df
# Out:
#               Date Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26  26  November  2013            19     Youth (<25)
# 1       2015-11-26  26  November  2015            19     Youth (<25)
# 2       2014-03-23  23     March  2014            49  Adults (35-64)
# 3       2016-03-23  23     March  2016            49  Adults (35-64)
# 4       2014-05-15  15       May  2014            47  Adults (35-64)
# ...            ...  ..       ...   ...           ...             ...
# 113031  2016-04-12  12     April  2016            41  Adults (35-64)
# 113032  2014-04-02   2     April  2014            18     Youth (<25)
# 113033  2016-04-02   2     April  2016            18     Youth (<25)
# 113034  2014-03-04   4     March  2014            37  Adults (35-64)
# 113035  2016-03-04   4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
#df.drop('level_0',axis=1,inplace=True)
#df.drop('index',axis=1,inplace=True)
df
# Out:
#               Date Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26  26  November  2013            19     Youth (<25)
# 1       2015-11-26  26  November  2015            19     Youth (<25)
# 2       2014-03-23  23     March  2014            49  Adults (35-64)
# 3       2016-03-23  23     March  2016            49  Adults (35-64)
# 4       2014-05-15  15       May  2014            47  Adults (35-64)
# ...            ...  ..       ...   ...           ...             ...
# 113031  2016-04-12  12     April  2016            41  Adults (35-64)
# 113032  2014-04-02   2     April  2014            18     Youth (<25)
# 113033  2016-04-02   2     April  2016            18     Youth (<25)
# 113034  2014-03-04   4     March  2014            37  Adults (35-64)
# 113035  2016-03-04   4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
#Parse your Calculated_Date column into a datetime object
df.head()
df.Calculated_Date=pd.to_datetime(df['Calculated_Date'])
df
# Out:
#               Date Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26  26  November  2013            19     Youth (<25)
# 1       2015-11-26  26  November  2015            19     Youth (<25)
# 2       2014-03-23  23     March  2014            49  Adults (35-64)
# 3       2016-03-23  23     March  2016            49  Adults (35-64)
# 4       2014-05-15  15       May  2014            47  Adults (35-64)
# ...            ...  ..       ...   ...           ...             ...
# 113031  2016-04-12  12     April  2016            41  Adults (35-64)
# 113032  2014-04-02   2     April  2014            18     Youth (<25)
# 113033  2016-04-02   2     April  2016            18     Youth (<25)
# 113034  2014-03-04   4     March  2014            37  Adults (35-64)
# 113035  2016-03-04   4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
#How did sales evolve through the years?
df.head()
df.groupby('Year')['Revenue'].sum()
# Out:
# Year
# 2011     8964888
# 2012     9175983
# 2013    15240037
# 2014    14152724
# 2015    20023991
# 2016    17713385
# Name: Revenue, dtype: int64

# %%
df['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
#Increase 50 U$S revenue to every sale
df.head()
df['Revenue']=df['Revenue']+50

# %%
#How many orders were made in Canada or France?
df.head(5)
sf=df.loc[(df['Country'] == 'Canada') | (df['Country'] == 'France')]
sf['Country'].value_counts().sum()
# Out:
# 25176

# %%
#How many Bike Racks orders were made from Canada?
df.head()
new_df=df[df['Country']=='Canada']
sf=new_df[new_df['Sub_Category']=='Bike Racks']
sf['Sub_Category'].value_counts()
# Out:
# Bike Racks    104
# Name: Sub_Category, dtype: int64

# %%
#How many orders were made in each region (state) of France?
df.head(5)
new_df=df[df['Country']=='France']
new_df['State'].value_counts().plot(kind='bar',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
#How many sales were made per category?
df.head()
df['Product_Category'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Product_Category'>

# %%
#How many orders were made per accessory sub-categories?
df.head(5)
df.groupby('Product_Category')['Sub_Category'].value_counts().plot(kind='bar',figsize=(8,8))
# Out:
# <AxesSubplot:xlabel='Product_Category,Sub_Category'>

# %%
#How many orders were made per bike sub-categories?
df.head(5)
sf=df[df.Product_Category=='Bikes']
sf.groupby('Product_Category')['Sub_Category'].value_counts().plot(kind='pie',figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='Sub_Category'>

# %%
#Which gender has the most amount of sales?
df.head(5)
df.Customer_Gender.value_counts().plot(kind='bar',figsize=(6,6))
# Out:
# <AxesSubplot:>

# %%
#How many sales with more than 500 in Revenue were made by men?
df.head()
new_df=df.loc[(df['Revenue']>500)&(df['Customer_Gender']=="M")]
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23342 entries, 0 to 113033
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              23342 non-null  object
#  1   Day               23342 non-null  object
#  2   Month             23342 non-null  object
#  3   Year              23342 non-null  object
#  4   Customer_Age      23342 non-null  int64
#  5   Age_Group         23342 non-null  object
#  6   Customer_Gender   23342 non-null  object
#  7   Country           23342 non-null  object
#  8   State             23342 non-null  object
#  9   Product_Category  23342 non-null  object
#  10  Sub_Category      23342 non-null  object
#  11  Product           23342 non-null  object
#  12  Order_Quantity    23342 non-null  int64
#  13  Unit_Cost         23342 non-null  int64
#  14  Unit_Price        23342 non-null  int64
#  15  Profit            23342 non-null  int64
# ...

# %%
#Get the top-5 sales with the highest revenue
df.head(5)
df.sort_values(['Revenue'],ascending=False).head(5)
# Out:
#               Date Day      Month  Year  Customer_Age       Age_Group  \
# 112073  2015-07-24  24       July  2015            52  Adults (35-64)
# 112072  2013-07-24  24       July  2013            52  Adults (35-64)
# 71129   2011-07-08   8       July  2011            22     Youth (<25)
# 70307   2011-04-30  30      April  2011            44  Adults (35-64)
# 70601   2011-09-30  30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70307                M     Canada  British Columbia            Bikes
# 70601                F     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %%
#What is the mean Order_Quantity of orders with more than 10K in revenue?
df.head(5)
new_df=df[df['Revenue']>10000]
new_df['Order_Quantity'].mean()
# Out:
# 3.689265536723164

# %%
#What is the mean Order_Quantity of orders with less than 10K in revenue?
df.head(5)
new_df=df[df['Revenue']<10000]
new_df['Order_Quantity'].mean()
# Out:
# 11.914539380997528

# %%
#How many orders were made in May of 2016?
df.head(3)
df.loc[(df['Year']=='2016') & (df['Month']=='May')].shape[0]
# Out:
# 5015

# %%
#How many orders were made between May and July of 2016?
df.head(3)
new_df=df.loc[(df['Year']=='2016') & ((df['Month']=='May') | (df['Month']=='July')|(df['Month']=='June'))]
new_df[['Month','Profit']].boxplot(by='Month',figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'Profit'}, xlabel='[Month]'>
